# %%
# !python -m pip install word2number
# Out:
# Requirement already satisfied: word2number in c:\users\prince raj\anaconda3\lib\site-packages (1.1)

# %%
import pandas as pd
from word2number import w2n
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("hiring.csv")
df
# Out:
#   experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0        NaN                    8.0                           9      50000
# 1        NaN                    8.0                           6      45000
# 2       five                    6.0                           7      60000
# 3        two                   10.0                          10      65000
# 4      seven                    9.0                           6      70000
# 5      three                    7.0                          10      62000
# 6        ten                    NaN                           7      72000
# 7     eleven                    7.0                           8      80000

# %%
df.head(10)
# Out:
#   experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0        NaN                    8.0                           9      50000
# 1        NaN                    8.0                           6      45000
# 2       five                    6.0                           7      60000
# 3        two                   10.0                          10      65000
# 4      seven                    9.0                           6      70000
# 5      three                    7.0                          10      62000
# 6        ten                    NaN                           7      72000
# 7     eleven                    7.0                           8      80000

# %%
m = df["test_score(out of 10)"].mean()
df["test_score(out of 10)"] = df["test_score(out of 10)"].fillna(m)

# %%
df["experience"] = df["experience"].fillna("zero")
df["experience"] = df["experience"].apply(w2n.word_to_num)

# %%
input_=df.drop(columns="salary($)")
output_= df["salary($)"]

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(input_ ,output_)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
predicted = lr.predict(input_)
predicted
# Out:
# array([52313.61238494, 45722.68644263, 58231.95591138, 63991.7318464 ,
#        67429.06277517, 61080.55179794, 75922.72532666, 79307.67351488])

# %%
df["predicted"] = predicted
df
# Out:
#    experience  test_score(out of 10)  interview_score(out of 10)  salary($)  \
# 0           0               8.000000                           9      50000
# 1           0               8.000000                           6      45000
# 2           5               6.000000                           7      60000
# 3           2              10.000000                          10      65000
# 4           7               9.000000                           6      70000
# 5           3               7.000000                          10      62000
# 6          10               7.857143                           7      72000
# 7          11               7.000000                           8      80000
#
#       predicted
# 0  52313.612385
# 1  45722.686443
# 2  58231.955911
# 3  63991.731846
# 4  67429.062775
# 5  61080.551798
# 6  75922.725327
# 7  79307.673515

# %%
input_.head(1)
# Out:
#    experience  test_score(out of 10)  interview_score(out of 10)
# 0           0                    8.0                           9

# %%
exp = float(input("Experience: "))
t_score = float(input("Test Score: "))
i_score = float(input("Interview Score: "))

user_pred = lr.predict([[exp, t_score, i_score]])

print("Predicted Salary $:", round(user_pred[0], 2))
# Out:
# Experience: 5
# Test Score: 6
# Interview Score: 5
# Predicted Salary $: 53838.01

# %%
plt.figure(figsize=(8, 5))

plt.plot(df.index, output_, label="Actual Salary", marker="o")
plt.plot(df.index, predicted, label="Predicted Salary", marker="x")

plt.scatter(len(df),user_pred[0],color="red",label="Your Predicted Salary",s=100,marker="*")

plt.xlabel("Data Point Index")
plt.ylabel("Salary ($)")
plt.title("Actual vs Predicted Salary")
plt.legend()
plt.grid(True)
plt.show()
